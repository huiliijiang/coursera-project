# %% [markdown]
# # COURSERA TORONTO

# %%
import pandas as pd
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

df=pd.read_html(url, header=0)[0]

df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
#drop unassigned
df.drop(df[df['Borough']=="Not assigned"].index,axis=0, inplace=True)
#combine same postal
df_1=df.groupby("Postcode").agg(lambda x:','.join(set(x)))
df_1
# Not
# Out:
#                    Borough                                      Neighbourhood
# Postcode
# M1B            Scarborough                                      Rouge,Malvern
# M1C            Scarborough               Highland Creek,Rouge Hill,Port Union
# M1E            Scarborough                    Morningside,Guildwood,West Hill
# M1G            Scarborough                                             Woburn
# M1H            Scarborough                                          Cedarbrae
# M1J            Scarborough                                Scarborough Village
# M1K            Scarborough          Kennedy Park,East Birchmount Park,Ionview
# M1L            Scarborough                      Oakridge,Golden Mile,Clairlea
# M1M            Scarborough      Cliffside,Scarborough Village West,Cliffcrest
# M1N            Scarborough                         Cliffside West,Birch Cliff
# M1P            Scarborough  Scarborough Town Centre,Wexford Heights,Dorset...
# M1R            Scarborough                                   Wexford,Maryvale
# M1S            Scarborough                                          Agincourt
# M1T            Scarborough              Tam O'Shanter,Sullivan,Clarks Corners
# M1V            Scarborough  L'Amoreaux East,Milliken,Steeles East,Agincour...
# M1W            Scarborough                                    L'Amoreaux West
# M1X            Scarborough                                        Upper Rouge
# M2H             North York                                  Hillcrest Village
# M2J             North York                         Fairview,Oriole,Henry Farm
# M2K             North York                                    Bayview Village
# M2L             North York                            York Mills,Silver Hills
# M2M             North York                             Newtonbrook,Willowdale
# M2N             North York                                   Willowdale South
# M2P             North York                                    York Mills West
# M2R             North York                                    Willowdale West
# M3A             North York                                          Parkwoods
# M3B             North York                                    Don Mills North
# M3C             North York                    Flemingdon Park,Don Mills South
# M3H             North York      Wilson Heights,Downsview North,Bathurst Manor
# M3J             North York                     Northwood Park,York University
# ...                    ...                                                ...
# M6C                   York                                 Humewood-Cedarvale
# M6E                   York                                Caledonia-Fairbanks
# M6G       Downtown Toronto                                           Christie
# M6H           West Toronto                        Dovercourt Village,Dufferin
# M6J           West Toronto                            Little Portugal,Trinity
# M6K           West Toronto         Exhibition Place,Brockton,Parkdale Village
# M6L             North York                   Downsview,North Park,Upwood Park
# M6M                   York        Silverthorn,Mount Dennis,Del Ray,Keelesdale
# M6N                   York                       The Junction North,Runnymede
# M6P           West Toronto                       The Junction South,High Park
# M6R           West Toronto                              Roncesvalles,Parkdale
# M6S           West Toronto                                  Swansea,Runnymede
# M7A           Queen's Park                                       Not assigned
# M7R            Mississauga              Canada Post Gateway Processing Centre
# M7Y           East Toronto  Business Reply Mail Processing Centre 969 Eastern
# M8V              Etobicoke         Mimico South,Humber Bay Shores,New Toronto
# M8W              Etobicoke                              Alderwood,Long Branch
# M8X              Etobicoke        The Kingsway,Montgomery Road,Old Mill North
# M8Y              Etobicoke  Royal York South East,Old Mill South,Kingsway ...
# M8Z              Etobicoke  Mimico NW,The Queensway West,South of Bloor,Ro...
# M9A              Etobicoke                                   Islington Avenue
# M9B              Etobicoke  Martin Grove,West Deane Park,Cloverdale,Prince...
# M9C              Etobicoke  Old Burnhamthorpe,Eringate,Markland Wood,Bloor...
# M9L             North York                                      Humber Summit
# M9M             North York                                    Humberlea,Emery
# M9N                   York                                             Weston
# M9P              Etobicoke                                          Westmount
# M9R              Etobicoke  St. Phillips,Kingsview Village,Martin Grove Ga...
# M9V              Etobicoke  Albion Gardens,Humbergate,Mount Olive,South St...
# M9W              Etobicoke                                          Northwest
#
# [103 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-69ac6f795ca9> in <module>()
# ----> 1 df.drop("Not",axis=0)
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3739             if errors != 'ignore':
#    3740                 raise ValueError('labels %s not contained in axis' %
# -> 3741                                  labels[mask])
#    3742             indexer = indexer[~mask]
#    3743         return self.delete(indexer)
#
# ValueError: labels ['Not'] not contained in axis
